# %% [markdown]
# ## 共通設定
# ハンズオン全体で使用する共通設定を定義します。
# ### スキーマ構成
# | スキーマ | 用途 | 言語 |
# |---------|------|------|
# | `ricoh_handson_nocode` | No-Code Agent (Genie/KA/MAS) | 英語 |
# | `ricoh_handson_code` | Code Agent (LangGraph/MLflow) | 日本語 |

# %%
# カタログ設定
catalog = "yao_sl_st_catalog"

# スキーマ設定（2つ）
schema_nocode = "ricoh_handson_nocode"  # No-Code Agent用（英語データ）
schema_code = "ricoh_handson_code"      # Code Agent用（日本語データ）

# 後方互換用（Day 2等で使用）
schema = dbName = db = schema_code
volume_name = "raw_data"

# Vector Search設定
VECTOR_SEARCH_ENDPOINT_NAME = "ricoh_vs_endpoint"

# LLM設定
LLM_ENDPOINT_NAME = "yao-ai-agent-demo-gateway"
NOCODE_LLM_ENDPOINT_NAME = "databricks-gpt-5-2"
EMBEDDING_MODEL_NAME = "databricks-qwen3-embedding-0-6b"

# AI Gateway設定
AI_GATEWAY_URL = "https://7474654222866971.ai-gateway.cloud.databricks.com/mlflow/v1"

# Agent設定
MODEL_NAME = "ricoh_technova_agent"
ENDPOINT_NAME = f'{MODEL_NAME}_{catalog}_{db}'[:60]

# %%
print(f"カタログ: {catalog}")
print(f"スキーマ (No-Code): {schema_nocode}")
print(f"スキーマ (Code): {schema_code}")
print(f"LLMエンドポイント (Code): {LLM_ENDPOINT_NAME}")
print(f"LLMエンドポイント (No-Code): {NOCODE_LLM_ENDPOINT_NAME}")
print(f"AI Gateway: {AI_GATEWAY_URL}")
print(f"埋め込みモデル: {EMBEDDING_MODEL_NAME}")
print(f"Vector Search EP: {VECTOR_SEARCH_ENDPOINT_NAME}")
